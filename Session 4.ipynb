# %% [markdown]
# # Session 4
#
# ## Key topics from last time
#
# 1. Laminar duct flow
# 2. Hydraulic diameter
# 3. Uniform wall heat flux
# 4. Hagen-Poiseuille flow
# 5. Entrance regions

# %% [markdown]
# # Turbulent Flow
#
# ![image.png](attachment:image.png)
#
# The maximum Reynolds number at which laminar flow in a pipe is always stable is around 2100. $Re_{critical}\ =\ u_\infty x_l / \nu$ where $x_l$ is the distance down the pipe. At long distances, the boundary layer exhibits vortex-like instabilities and transitions into a fully turbulent boundary layer. This can occur when $Re_x\ >\ 30,000$. It is interesting to note that these critical numbers are more or less universal, from experimental observations.
#
# Since local velocities in turbulent flow fluctuate due to the existence of eddies and vortices from non-uniform variations in momenta, we consider the time-averaged velocity: $\overline{u}\ =\ 1/T \int _0^T u dt$ where T is an interval of time much longer than the period of fluctuations.
#
# Similarly, the shear stress has fluctuations: $\tau _w\ =\ \rho (\nu\ +\ \epsilon _m) \partial \overline{u}/\partial y$
#
# Unlike laminar flow, turbulent flow transfers heat and momentum via vertical motion of vertices, rather than gradual molecular diffusion. As a result, gradients in velocity and temperature are very high near the surface.
#
# The very thin region near the wall is called the viscous sub-layer (tens to hundreds of micrometers thick). In the sub-layer, heat transport is controlled by heat conduction.
#
# Further away, larger vortices imply that turbulent shear stress dominates ($\epsilon _m\ >>\ \nu$), as well as turbulent mixing being the dominant mode of heat transport.
#
# As an addition to Fourier's law for conduction, Boussiesq introduced an eddy diffusivity term for turbulent flow, where: $q\ =\ -k\partial \overline{T}/\partial y\ -\ \rho c_p \epsilon _h \partial \overline{T}/\partial y$, where $\overline{T}$ is the local time averaged temperature, and $\epsilon _h$ is the eddy diffusivity for heat.
#
# We introduce a Stanton number ($St\ =\ h/\rho c_p u_\infty$) and obtain the Reynolds-Colburn analogy for turbulent flow: $St\ =\ Nu_x/Re_x Pr\ =\ C_f/2 / 1\ +\ 12.7(Pr^{2/3}\ -\ 1)\sqrt{C_f/2}$.
#
# $C_f$ is the skin friction coefficient (dimensionless frictional stress value) that relates the wall shear stress to the velocity: $C_f\ =\ \tau _w/ 1/2 \rho U_\infty^2\ =\ 0.664/\sqrt{Re_x}$ for laminar flow. For turbulent flow: $C_f (x)\ =\ 0.455/[ln(0.06 Re_x)]^2$ to 1-2% accuracy for any Reynold's number.
#
# Reynolds measured turbulent air flow over constant temperature plates and obtained a lot of experimental data:
#
# ![image-2.png](attachment:image-2.png)
#
# from which he proposed a simpler correlation: $Nu_x\ =\ 0.0296 Re_x^{0.8} Pr^{0.6}$ for gases. This holds accurately for most gases which have a similar Pr. However, fluids with higher Pr numbers will deviate, and primarily follow the following trend as proposed by Zukauskas: $Nu_x\ =\ 0.032 Re_x^{0.8} Pr^{0.43}$.

# %% [markdown]
# ## Turbulent transition
#
# From above, h can be calculated in both the laminar and fully turbulent region of the boundary layer. However, there is still a transition region we need to account for. From experiments, it is known that Nu rises steeply in the transition region
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
#
# Putting it all together, Churchill fit all laminar, transition and fully turbulent profiles, and then Lienhard simplified the formula to: $Nu_x\ =\ [Nu_{x,lam}^5\ +\ (Nu_{x,trans}^{-10}\ +\ Nu_{x,turb}^{-10})^{-1/2}]^{1/5}$.

# %% [markdown]
# # COMSOL tutorial and example
#
#
# https://docs.google.com/document/d/1wa0VjpVZYFThMIZOj4Aonj8Ar4-aaYHp4bz8iquSz3Y/edit?usp=drive_link

# %% [markdown]
# # Problem Set 4
#
# 1. Air flows at -10 degrees Celsius over a smooth, sharp-edged surface at 240 km/hr. The surface is at 10 degC. Turbulent transition begins at $Re_L\ =\ 140,000$ and ends at $Re_u\ =\ 315,000$
#
# a) What are the x-coordinates within which the laminar-to-turbulent transition occurs
#
# b) What is the average heat transfer coefficient over a 2 meter long surface
#
# c) h at the trailing edge for a 2 meter surface
#
# d) boundary layer thickness and h at $x_l$
#
# 2.
#
# ![image.png](attachment:image.png)
#
# Equation 6.112 from L&L: $Nu_x\ =\ 0.0296 Re_x^{0.8} Pr^{0.6}$ for gases, as measured by Reynolds for turbulent air flow over a constant temperature plate
#
# 3. Use COMSOL to model a 2D cross-section of a duct, with 1 m in width and 3 m in length, inlet velocity as 4 m/s, inlet temperature at 30degC and constant wall heat flux at 5 W/m^2. Use the results to determine the temperature profile
